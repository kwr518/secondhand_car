# %%
import numpy as np
import pandas as pd
import sqlite3
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, LeakyReLU, Input
from tensorflow.keras.optimizers import Adam


# 데이터베이스에서 데이터 로드
def load_data():
    conn = sqlite3.connect("database.db")
    query = "SELECT * FROM use_data"
    df = pd.read_sql_query(query, conn)
    conn.close()
    return df


# 데이터베이스에 저장
def save_data_to_db(data, table_name="gan_data"):
    conn = sqlite3.connect("database.db")
    data.to_sql(table_name, conn, if_exists="replace", index=False)
    conn.close()
    print(f"{table_name} 테이블에 데이터가 저장되었습니다.")


# 데이터 전처리
def preprocess_data(df):
    # 모든 데이터를 정규화 (0~1)
    normalized_data = (df - df.min()) / (df.max() - df.min())
    return normalized_data, df.columns.tolist()


# 역정규화
def inverse_transform(data, original_df, columns):
    for col in columns:
        data[col] = data[col] * (original_df[col].max() - original_df[col].min()) + original_df[col].min()
    return data


# GAN 모델 설계
def build_gan(input_dim):
    # 생성자
    generator = Sequential([
        Input(shape=(input_dim,)),
        Dense(128),
        LeakyReLU(0.2),
        Dense(256),
        LeakyReLU(0.2),
        Dense(input_dim, activation='sigmoid')
    ])

    # 판별자
    discriminator = Sequential([
        Input(shape=(input_dim,)),
        Dense(256),
        LeakyReLU(0.2),
        Dense(128),
        LeakyReLU(0.2),
        Dense(1, activation='sigmoid')
    ])
    discriminator.compile(loss='binary_crossentropy', optimizer=Adam(0.0002, 0.5))

    # GAN 모델
    discriminator.trainable = False
    gan_input = Input(shape=(input_dim,))
    generated_data = generator(gan_input)
    gan_output = discriminator(generated_data)
    gan = Model(gan_input, gan_output)
    gan.compile(loss='binary_crossentropy', optimizer=Adam(0.0002, 0.5))

    return generator, discriminator, gan


# GAN 학습
def train_gan(generator, discriminator, gan, data, epochs=5000, batch_size=32):
    for epoch in range(epochs):
        try:
            # 실제 데이터 샘플링
            real_data = data.sample(batch_size, replace=True).values  # NumPy 배열로 변환
            real_labels = np.ones((batch_size, 1))  # 실제 데이터 라벨

            # 가짜 데이터 생성
            noise = np.random.normal(0, 1, (batch_size, data.shape[1]))
            fake_data = generator.predict(noise)
            fake_labels = np.zeros((batch_size, 1))  # 가짜 데이터 라벨

            # 판별자 학습
            discriminator.trainable = True

            d_loss_real = discriminator.train_on_batch(real_data, real_labels)
            d_loss_fake = discriminator.train_on_batch(fake_data, fake_labels)
            d_loss = 0.5 * (d_loss_real + d_loss_fake)  # 단순 평균
            

            # 생성자 학습
            discriminator.trainable = False
            noise = np.random.normal(0, 1, (batch_size, data.shape[1]))
            valid_labels = np.ones((batch_size, 1))  # 생성자 학습 라벨은 '진짜'로 설정
            g_loss = gan.train_on_batch(noise, valid_labels)

            # 진행 상황 출력
            if epoch % 100 == 0:
                print(f"Epoch {epoch} | D Loss: {d_loss:.4f} | G Loss: {g_loss:.4f}")

        except Exception as e:
            print(f"C {epoch}에서 오류 발생: {e}")


# 메인 실행
def main():
    # 데이터 로드
    df = load_data()

    # 데이터 전처리
    normalized_data, columns = preprocess_data(df)

    # GAN 모델 생성
    input_dim = normalized_data.shape[1]
    generator, discriminator, gan = build_gan(input_dim)

    # GAN 학습
    train_gan(generator, discriminator, gan, normalized_data)

    # 새로운 데이터 생성
    num_samples = 1000
    noise = np.random.normal(0, 1, (num_samples, input_dim))
    generated_data = generator.predict(noise)

    # 데이터 역정규화
    generated_data = pd.DataFrame(generated_data, columns=columns)
    generated_data = inverse_transform(generated_data, df, columns)

    # 데이터 저장
    save_data_to_db(generated_data)


if __name__ == "__main__":
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# C 0에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 1에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 2에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C 3에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C 4에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 5에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C 6에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C 7에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 8에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C 9에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C 10에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C 11에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# C 12에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 13에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 14에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C 15에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# C 16에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# C 17에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 18에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# C 19에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C 20에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# C 21에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# C 22에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C 23에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 24에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# C 25에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C 26에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C 27에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 28에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# C 29에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 30에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# C 31에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C 32에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C 33에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# C 34에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# C 35에서 오류 발생: 'NoneType' object has no attribute 'update_state'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 138
#     134     save_data_to_db(generated_data)
#     137 if __name__ == "__main__":
# --> 138     main()
#
# Cell In[5], line 122, in main()
#     119 generator, discriminator, gan = build_gan(input_dim)
#     121 # GAN 학습
# --> 122 train_gan(generator, discriminator, gan, normalized_data)
#     124 # 새로운 데이터 생성
#     125 num_samples = 1000
#
# Cell In[5], line 84, in train_gan(generator, discriminator, gan, data, epochs, batch_size)
#      82 # 가짜 데이터 생성
#      83 noise = np.random.normal(0, 1, (batch_size, data.shape[1]))
# ---> 84 fake_data = generator.predict(noise)
#      85 fake_labels = np.zeros((batch_size, 1))  # 가짜 데이터 라벨
#      87 # 판별자 학습
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:556, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     554 outputs = None
#     555 with epoch_iterator.catch_stop_iteration():
# --> 556     for step, iterator in epoch_iterator:
#     557         callbacks.on_predict_batch_begin(step)
#     558         data = get_data(iterator)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:729, in TFEpochIterator.__next__(self)
#     728 def __next__(self):
# --> 729     return next(self._epoch_iterator)
#
# File ~\anaconda3\Lib\site-packages\keras\src\trainers\epoch_iterator.py:102, in EpochIterator._enumerate_iterator(self)
#     100 if steps_per_epoch > 0:
#     101     if self._current_iterator is None or self.steps_per_epoch is None:
# --> 102         self._current_iterator = iter(self._get_iterator())
#     103         self._steps_seen = 0
#     104     for step in range(0, steps_per_epoch, self.steps_per_execution):
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3509, in make_iterator(dataset, iterator, name)
#    3507 if tld.is_eager:
#    3508   try:
# -> 3509     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3510       _ctx, "MakeIterator", name, dataset, iterator)
#    3511     return _result
#    3512   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
